# %%
def judge_palindrome(seq):
    complement_code={"A":"T","T":"A","G":"C","C":"G",}
    if len(seq)%2 != 0:
        return False
    else:
        for i in range(len(seq)//2):
            if seq[i] != complement_code[seq[len(seq)-i-1]]:
                return False
        return True
    
DNA_seq="..."
for i in range(len(DNA_seq)):
    for j in range(4,13,2):
        #print(j)
        if i+j<=len(DNA_seq):
            #print("Y")
            #print(DNA_seq[i:i+j])
            if judge_palindrome(DNA_seq[i:i+j]):
                #print("Y")
                print(i+1,j)
                #print(DNA_seq[i:i+j])
# Out:
# 1 4
# 6 4
# 20 4
# 23 4
# 28 4
# 28 10
# 29 8
# 30 6
# 31 4
# 34 4
# 46 4
# 50 4
# 58 4
# 65 4
# 67 4
# 81 4
# 84 4
# 107 6
# 108 4
# 110 6
# 111 4
# 113 4
# 118 4
# 135 4
# 140 4
# 142 6
# 143 4
# 148 4
# 156 4
# 163 8
# 164 6
# 165 4
# 167 10
# 168 8
# 169 6
# 170 4
# 174 4
# 189 4
# 194 6
# 195 4
# 218 4
# 224 4
# 232 4
# 240 6
# 241 4
# 260 6
# 261 4
# 266 8
# 267 6
# 268 4
# 278 4
# 325 6
# 326 4
# 367 4
# 372 4
# 377 4
# 390 4
# 403 4
# 424 4
# 440 4
# 440 12
# 441 10
# 442 8
# 443 6
# 444 4
# 448 4
# 464 4
# 469 4
# 482 4
# 508 4
# 509 4
# 524 4
# 534 4
# 547 4
# 562 4
# 585 4
# 601 4
# 632 4
# 649 4
# 655 6
# 656 4
# 679 4
# 718 4
# 722 4
# 735 4
# 740 6
# 741 4
# 743 4
# 754 4
# 772 4
# 780 4
# 796 12
# 797 10
# 798 8
# 799 6
# 800 4
# 829 4
# 839 4
# 843 4
# 844 6
# 845 4
# 863 4
# 878 4
# 883 4
# 887 4
